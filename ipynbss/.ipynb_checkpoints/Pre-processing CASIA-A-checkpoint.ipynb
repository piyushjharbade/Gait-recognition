# %%
import os
os.chdir('C:\\Users\\91898\\mlenv')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\91898\\mlenv'

# %% [markdown]
# __Hardcodded

# %%
from scipy.signal import argrelextrema
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt

# Folder paths
silhouette_folder = os.path.join("CASIA-a", "GaitDatasetA-silh", "GaitDatasetA-silh", "fyc", "90_3")
white_pixel_threshold = 150 # Minimum white pixel count for a frame to be considered

# Extract the folder name (last part of the path)
folder_name = os.path.basename(silhouette_folder)
# Extract angle from folder name
angle = folder_name.split('_')[0]  # Get the first part before '_'
# Convert to integer
angle = int(angle)
print(f"Extracted Angle: {angle}°")
frame_ignoring_factor=0.1
if(angle==45):
    frame_ignoring_factor=0.25

# Function to count white pixels in the lower half of the image
def count_white_pixels_lower_half(img):
    height, width = img.shape
    if angle == 45:
        lower_half = img[(height//2)+16:, :]  # Extract the lower half
    else:
        lower_half = img[(height//2):, :]
    return np.count_nonzero(lower_half)


# Function to compute centroid of the silhouette
def compute_centroid(img):
    y_indices, x_indices = np.where(img > 0)  # Find all white pixel positions
    if len(y_indices) == 0:  # No silhouette detected
        return None
    centroid_y = np.mean(y_indices)
    return centroid_y

# Read all frame files
image_files = sorted(os.listdir(silhouette_folder))

if angle == 90:
    # Determine if white pixel count is increasing or decreasing
    white_pixel_counts_temp = []
    for img_file in image_files:
        frame_path = os.path.join(silhouette_folder, img_file)
        img = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
        white_pixel_counts_temp.append(count_white_pixels_lower_half(img))
    
    if white_pixel_counts_temp[0] < white_pixel_counts_temp[-1]:
        # Increasing trend, ignore first 25%
        ignore_count = int(0.25 * len(image_files))
        image_files = image_files[ignore_count:]
    else:
        # Decreasing trend, ignore last 25%
        ignore_count = int(0.25 * len(image_files))
        image_files = image_files[:-ignore_count]
else:
    # Ignore first 25% of frames for other angles
    ignore_count = int(0.25 * len(image_files))
    image_files = image_files[ignore_count:]


# Extract white pixel count for each frame
frame_pixel_counts = []
frame_numbers = []
centroid_positions = []


for img_file in image_files:
    frame_path = os.path.join(silhouette_folder, img_file)
    img = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
    
    frame_number = int(os.path.splitext(img_file)[0].split('-')[-1])  # Extract numeric frame number
    white_pixel_count = count_white_pixels_lower_half(img)
    if angle==90:
            centroid_y = compute_centroid(img)


    if white_pixel_count >= white_pixel_threshold:  # Only keep significant frames
        frame_pixel_counts.append(white_pixel_count)
        frame_numbers.append(frame_number)
        if angle ==90:
            centroid_positions.append(centroid_y)


frame_pixel_counts_np = np.array(frame_pixel_counts)
if angle ==90:
    centroid_positions_np = np.array(centroid_positions)
    # **90-degree case: Centroid Tracking Method**
    # Detect valleys (local minima) in centroid y-coordinates
    valley_indices = argrelextrema(centroid_positions_np, np.less, order=3)[0]
    valley_frames = [frame_numbers[i] for i in valley_indices]
    # Use first and third valley as gait cycle
    if len(valley_frames) >= 3:
        first_valley_frame = valley_frames[0]
        third_valley_frame = valley_frames[2]
        print(f"90° Gait Cycle Detected: Frame {first_valley_frame} to {third_valley_frame}")
    else:
        print("Not enough valleys detected for gait cycle.")
        first_valley_frame, third_valley_frame = None, None

else:
    # Compute max pixel count and set a threshold
    max_pixel_count = np.max(frame_pixel_counts_np)
    pixel_count_threshold = 0.2 * max_pixel_count  # 20% of max pixel count

    # Ignore peaks/valleys below this threshold
    valid_indices = [i for i in range(len(frame_pixel_counts)) if frame_pixel_counts[i] > pixel_count_threshold]

    # Detect **peaks** (local maxima)
    peak_indices = argrelextrema(frame_pixel_counts_np, np.greater, order=3)[0]
    peak_indices = [i for i in peak_indices if i in valid_indices]  # Filter peaks

    # Detect **valleys** (local minima)
    valley_indices = argrelextrema(frame_pixel_counts_np, np.less, order=3)[0]
    valley_indices = [i for i in valley_indices if i in valid_indices]  # Filter valleys


    # Convert indices to actual frame numbers
    peak_frames = [frame_numbers[i] for i in peak_indices]
    valley_frames = [frame_numbers[i] for i in valley_indices]

    # Two-pointer approach to remove peak-valley pairs with less than 4-frame difference
    filtered_peak_frames = []
    filtered_valley_frames = []

    p, v = 0, 0  # Initialize peak and valley pointers

    while p < len(peak_frames) and v < len(valley_frames):
        peak = peak_frames[p]
        valley = valley_frames[v]

        if peak - valley >= 4:
            filtered_peak_frames.append(peak)
            filtered_valley_frames.append(valley)
            p += 1
            v += 1  # Move both pointers forward
        else:
            # Remove the closer peak-valley pair
            if peak < valley:
                p += 1  # Skip peak
            else:
                v += 1  # Skip valley

    # Update the lists with filtered peaks and valleys
    peak_frames = filtered_peak_frames
    valley_frames = filtered_valley_frames

    # **Step 1: Remove False Start & End Valleys**
    buffer_size = max(2, int(len(frame_pixel_counts) * frame_ignoring_factor))  # Ignore first & last 10% of frames
    filtered_valley_frames = [v for v in valley_frames if frame_numbers.index(v) > buffer_size and frame_numbers.index(v) < len(frame_pixel_counts) - buffer_size]

    # **Step 2: Select First and Third Valid Valley as Gait Cycle**
    if len(filtered_valley_frames) >= 3:
        first_valley_frame = filtered_valley_frames[0]
        third_valley_frame = filtered_valley_frames[2]
        print(f"Initial Gait Cycle: Frame {first_valley_frame} to {third_valley_frame}")
    else:
        print(" Not enough valid valleys detected to determine a gait cycle.")
        first_valley_frame, third_valley_frame = None, None
    
# **Step 4: Plot Results**
plt.figure(figsize=(10, 5))
plt.plot(frame_numbers, frame_pixel_counts, label="White Pixel Count", color='black')

if angle ==90:
    # Plot centroid movements
    plt.plot(frame_numbers, centroid_positions, label="Centroid Y-Position", color='orange')
    plt.scatter(valley_frames, [centroid_positions[frame_numbers.index(f)] for f in valley_frames], color='red', label="Centroid Valleys")

else:
    # Mark peaks
    plt.scatter(peak_frames, [frame_pixel_counts[frame_numbers.index(f)] for f in peak_frames], 
                color='green', label="Detected Peaks")

    # Mark filtered valleys
    plt.scatter(filtered_valley_frames, [frame_pixel_counts[frame_numbers.index(f)] for f in filtered_valley_frames], 
                color='red', label="Filtered Valleys")

    # Mark first and third valley if they exist
    if first_valley_frame and third_valley_frame:
        plt.axvline(x=first_valley_frame, color='blue', linestyle='--', label=f"Start: {first_valley_frame}")
        plt.axvline(x=third_valley_frame, color='purple', linestyle='--', label=f"End: {third_valley_frame}")

print(f"Frame ignoring factor: {frame_ignoring_factor}")
# Plot styling
plt.xlabel("Frame Number")
plt.ylabel("White Pixel Count")
plt.title("Filtered White Pixel Counts, Peaks, and Valley Detection")
plt.legend()
plt.show()
# Out:
# Extracted Angle: 90°
# 90° Gait Cycle Detected: Frame 5 to 40
# Frame ignoring factor: 0.1

# %% [markdown]
# Update 1

# %%
import numpy as np
import cv2
import os
from scipy.signal import argrelextrema
import matplotlib.pyplot as plt

# Configuration
silhouette_folder = os.path.join("CASIA-a", "GaitDatasetA-silh", "GaitDatasetA-silh", "fyc", "00_1")
white_pixel_threshold = 150  # Minimum white pixel count for a frame to be considered

# Extract angle from folder name
angle = int(os.path.basename(silhouette_folder).split('_')[0])
print(f"Extracted Angle: {angle}°")

# Set ignore factors
initial_ignore_factor = 0.25  # For initial frame ignoring
valley_ignore_factor = 0.25 if angle == 45 else 0.1  # For valley filtering in non-90° cases

# Helper Functions
def count_white_pixels_lower_half(img, angle):
    """Count white pixels in the lower half of the image, adjusted for angle."""
    height, width = img.shape
    lower_start = (height // 2) + 16 if angle == 45 else height // 2
    return np.count_nonzero(img[lower_start:, :])

def compute_centroid(img):
    """Compute the y-coordinate of the centroid of white pixels."""
    y_indices, _ = np.where(img > 0)
    return np.mean(y_indices) if len(y_indices) > 0 else np.nan

# Load all image files and compute data in one pass
image_files = sorted(os.listdir(silhouette_folder))
total_frames = len(image_files)

white_pixel_counts = []
centroids = [] if angle == 90 else None
frame_numbers_all = []

for img_file in image_files:
    frame_path = os.path.join(silhouette_folder, img_file)
    img = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
    frame_number = int(os.path.splitext(img_file)[0].split('-')[-1])
    white_pixel_count = count_white_pixels_lower_half(img, angle)
    white_pixel_counts.append(white_pixel_count)
    frame_numbers_all.append(frame_number)
    if angle == 90:
        centroids.append(compute_centroid(img))

# Convert to NumPy arrays
white_pixel_counts = np.array(white_pixel_counts)
frame_numbers_all = np.array(frame_numbers_all)
centroids = np.array(centroids) if angle == 90 else None

# Select frames based on angle and trend
if angle == 90:
    if white_pixel_counts[0] < white_pixel_counts[-1]:
        # Increasing trend: ignore first 25%
        start_idx = int(initial_ignore_factor * total_frames)
    else:
        # Decreasing trend: ignore last 25%
        start_idx = 0
        end_idx = int((1 - initial_ignore_factor) * total_frames)
        selected_indices = np.arange(start_idx, end_idx)
        selected_indices = selected_indices  # Assigned here to avoid UnboundLocalError
    selected_indices = np.arange(start_idx, total_frames)
else:
    # Ignore first 25% for other angles
    start_idx = int(initial_ignore_factor * total_frames)
    selected_indices = np.arange(start_idx, total_frames)

# Filter frames based on white pixel threshold
filter_indices = selected_indices[white_pixel_counts[selected_indices] >= white_pixel_threshold]
frame_numbers = frame_numbers_all[filter_indices]
signal = centroids[filter_indices] if angle == 90 else white_pixel_counts[filter_indices]

# Gait Cycle Detection
if angle == 90:
    if len(signal) > 0 and not np.all(np.isnan(signal)):
        valley_indices = argrelextrema(signal, np.less, order=3)[0]
        valley_frames = frame_numbers[valley_indices]
        if len(valley_frames) >= 3:
            first_valley_frame = valley_frames[0]
            third_valley_frame = valley_frames[2]
            print(f"90° Gait Cycle Detected: Frame {first_valley_frame} to {third_valley_frame}")
        else:
            print("Not enough valleys detected for gait cycle.")
            first_valley_frame, third_valley_frame = None, None
    else:
        print("No valid centroid data after filtering.")
        first_valley_frame, third_valley_frame = None, None
else:
    if len(signal) > 0:
        max_pixel_count = np.max(signal)
        pixel_count_threshold = 0.2 * max_pixel_count
        valid_mask = signal > pixel_count_threshold

        peak_indices = argrelextrema(signal, np.greater, order=3)[0]
        peak_indices = peak_indices[np.isin(peak_indices, np.where(valid_mask)[0])]
        valley_indices = argrelextrema(signal, np.less, order=3)[0]
        valley_indices = valley_indices[np.isin(valley_indices, np.where(valid_mask)[0])]

        peak_frames = frame_numbers[peak_indices]
        valley_frames = frame_numbers[valley_indices]

        # Filter peak-valley pairs
        filtered_peak_frames = []
        filtered_valley_frames = []
        p, v = 0, 0
        while p < len(peak_frames) and v < len(valley_frames):
            peak = peak_frames[p]
            valley = valley_frames[v]
            if abs(peak - valley) >= 4:
                filtered_peak_frames.append(peak)
                filtered_valley_frames.append(valley)
                p += 1
                v += 1
            elif peak < valley:
                p += 1
            else:
                v += 1

        # Remove false start/end valleys
        buffer_size = max(2, int(len(frame_numbers) * valley_ignore_factor))
        filtered_valley_frames = [
            v for v in filtered_valley_frames
            if buffer_size < np.where(frame_numbers == v)[0][0] < len(frame_numbers) - buffer_size
        ]

        if len(filtered_valley_frames) >= 3:
            first_valley_frame = filtered_valley_frames[0]
            third_valley_frame = filtered_valley_frames[2]
            print(f"Initial Gait Cycle: Frame {first_valley_frame} to {third_valley_frame}")
        else:
            print("Not enough valid valleys detected to determine a gait cycle.")
            first_valley_frame, third_valley_frame = None, None
    else:
        print("No valid frames after filtering.")
        first_valley_frame, third_valley_frame = None, None

# Plot Results
plt.figure(figsize=(10, 5))
plt.plot(frame_numbers, white_pixel_counts[filter_indices], label="White Pixel Count", color='black')

if angle == 90:
    if len(signal) > 0:
        plt.plot(frame_numbers, signal, label="Centroid Y-Position", color='orange')
        if 'valley_frames' in locals():
            plt.scatter(valley_frames, signal[valley_indices], color='red', label="Centroid Valleys")
else:
    if 'peak_frames' in locals():
        plt.scatter(peak_frames, signal[peak_indices], color='green', label="Detected Peaks")
    if 'filtered_valley_frames' in locals():
        valley_values = signal[[np.where(frame_numbers == v)[0][0] for v in filtered_valley_frames]]
        plt.scatter(filtered_valley_frames, valley_values, color='red', label="Filtered Valleys")
    if first_valley_frame and third_valley_frame:
        plt.axvline(x=first_valley_frame, color='blue', linestyle='--', label=f"Start: {first_valley_frame}")
        plt.axvline(x=third_valley_frame, color='purple', linestyle='--', label=f"End: {third_valley_frame}")

plt.xlabel("Frame Number")
plt.ylabel("Value")
plt.title(f"Gait Cycle Detection at {angle}°")
plt.legend()
plt.show()
# Out:
# Extracted Angle: 0°
# Initial Gait Cycle: Frame 25 to 51

# %%
import numpy as np
import cv2
import os
from scipy.signal import argrelextrema
import matplotlib.pyplot as plt

# Configuration
silhouette_folder = os.path.join("CASIA-a", "GaitDatasetA-silh", "GaitDatasetA-silh", "fyc", "00_4")
white_pixel_threshold = 150  # Minimum white pixel count for a frame to be considered

# Extract angle from folder name
angle = int(os.path.basename(silhouette_folder).split('_')[0])
print(f"Extracted Angle: {angle}°")

# Set ignore factors
initial_ignore_factor = 0.25  # For initial frame ignoring
valley_ignore_factor = 0.25 if angle == 45 else 0.1  # For valley filtering in non-90° cases

# Helper Functions
def count_white_pixels_lower_half(img, angle):
    """Count white pixels in the lower half of the image, adjusted for angle."""
    height, width = img.shape
    lower_start = (height // 2) + 16 if angle == 45 else height // 2
    return np.count_nonzero(img[lower_start:, :])

def compute_centroid(img):
    """Compute the y-coordinate of the centroid of white pixels."""
    y_indices, _ = np.where(img > 0)
    return np.mean(y_indices) if len(y_indices) > 0 else np.nan

# Load all image files and compute data in one pass
image_files = sorted(os.listdir(silhouette_folder))
total_frames = len(image_files)

white_pixel_counts = []
centroids = [] if angle == 90 else None
frame_numbers_all = []

for img_file in image_files:
    frame_path = os.path.join(silhouette_folder, img_file)
    img = cv2.imread(frame_path, cv2.IMREAD_GRAYSCALE)
    frame_number = int(os.path.splitext(img_file)[0].split('-')[-1])
    white_pixel_count = count_white_pixels_lower_half(img, angle)
    white_pixel_counts.append(white_pixel_count)
    frame_numbers_all.append(frame_number)
    if angle == 90:
        centroids.append(compute_centroid(img))

# Convert to NumPy arrays
white_pixel_counts = np.array(white_pixel_counts)
frame_numbers_all = np.array(frame_numbers_all)
centroids = np.array(centroids) if angle == 90 else None

# Select frames based on angle and trend
if angle == 90:
    if white_pixel_counts[0] < white_pixel_counts[-1]:
        # Increasing trend: ignore first 25%
        start_idx = int(initial_ignore_factor * total_frames)
    else:
        # Decreasing trend: ignore last 25%
        start_idx = 0
        end_idx = int((1 - initial_ignore_factor) * total_frames)
        selected_indices = np.arange(start_idx, end_idx)
    selected_indices = np.arange(start_idx, total_frames)
else:
    # Ignore first 25% for other angles
    start_idx = int(initial_ignore_factor * total_frames)
    selected_indices = np.arange(start_idx, total_frames)

# Filter frames based on white pixel threshold
filter_indices = selected_indices[white_pixel_counts[selected_indices] >= white_pixel_threshold]
frame_numbers = frame_numbers_all[filter_indices]
signal = centroids[filter_indices] if angle == 90 else white_pixel_counts[filter_indices]

# Gait Cycle Detection
first_valley_frame, third_valley_frame = None, None

if angle == 90:
    if len(signal) > 0 and not np.all(np.isnan(signal)):
        valley_indices = argrelextrema(signal, np.less, order=3)[0]
        valley_frames = frame_numbers[valley_indices]
        if len(valley_frames) >= 3:
            first_valley_frame = valley_frames[0]
            third_valley_frame = valley_frames[2]
            print(f"90° Gait Cycle Detected: Frame {first_valley_frame} to {third_valley_frame}")
        else:
            print("Not enough valleys detected for gait cycle at 90°.")
    else:
        print("No valid centroid data after filtering.")
else:
    if len(signal) > 0:
        max_pixel_count = np.max(signal)
        pixel_count_threshold = 0.2 * max_pixel_count
        valid_mask = signal > pixel_count_threshold

        peak_indices = argrelextrema(signal, np.greater, order=3)[0]
        peak_indices = peak_indices[np.isin(peak_indices, np.where(valid_mask)[0])]
        valley_indices = argrelextrema(signal, np.less, order=3)[0]
        valley_indices = valley_indices[np.isin(valley_indices, np.where(valid_mask)[0])]

        peak_frames = frame_numbers[peak_indices]
        valley_frames = frame_numbers[valley_indices]

        # Filter peak-valley pairs
        filtered_peak_frames = []
        filtered_valley_frames = []
        p, v = 0, 0
        while p < len(peak_frames) and v < len(valley_frames):
            peak = peak_frames[p]
            valley = valley_frames[v]
            if abs(peak - valley) >= 4:
                filtered_peak_frames.append(peak)
                filtered_valley_frames.append(valley)
                p += 1
                v += 1
            elif peak < valley:
                p += 1
            else:
                v += 1

        # Remove false start/end valleys
        buffer_size = max(2, int(len(frame_numbers) * valley_ignore_factor))
        filtered_valley_frames = [
            v for v in filtered_valley_frames
            if buffer_size < np.where(frame_numbers == v)[0][0] < len(frame_numbers) - buffer_size
        ]

        if len(filtered_valley_frames) >= 3:
            first_valley_frame = filtered_valley_frames[0]
            third_valley_frame = filtered_valley_frames[2]
            print(f"Initial Gait Cycle Detected: Frame {first_valley_frame} to {third_valley_frame}")
        else:
            print("Not enough filtered valleys detected for gait cycle.")
    else:
        print("No valid frames after filtering.")

# Fallback Mechanism
if first_valley_frame is None or third_valley_frame is None:
    if len(frame_numbers) > 0:
        fallback_used = True
        print("Primary detection failed. Using fallback: 20 frames from the middle.")
        if len(frame_numbers) >= 20:
            mid_idx = len(frame_numbers) // 2
            start_idx = max(0, mid_idx - 10)
            end_idx = min(len(frame_numbers), mid_idx + 10)
            selected_frames = frame_numbers[start_idx:end_idx]
            first_valley_frame = selected_frames[0]
            third_valley_frame = selected_frames[-1]
            print(f"Fallback Gait Cycle: Frames {first_valley_frame} to {third_valley_frame}")
        else:
            print("Too few frames, using all available frames.")
            first_valley_frame = frame_numbers[0]
            third_valley_frame = frame_numbers[-1]
            print(f"Fallback Gait Cycle (all frames): Frames {first_valley_frame} to {third_valley_frame}")
    else:
        print("No valid frames available for fallback.")
        fallback_used = False
else:
    fallback_used = False

# Plot Results
plt.figure(figsize=(10, 5))
plt.plot(frame_numbers, white_pixel_counts[filter_indices], label="White Pixel Count", color='black')

if angle == 90:
    if len(signal) > 0:
        plt.plot(frame_numbers, signal, label="Centroid Y-Position", color='orange')
        if 'valley_frames' in locals():
            plt.scatter(valley_frames, signal[valley_indices], color='red', label="Centroid Valleys")
else:
    if 'peak_frames' in locals():
        plt.scatter(peak_frames, signal[peak_indices], color='green', label="Detected Peaks")
    if 'filtered_valley_frames' in locals():
        valley_values = signal[[np.where(frame_numbers == v)[0][0] for v in filtered_valley_frames]]
        plt.scatter(filtered_valley_frames, valley_values, color='red', label="Filtered Valleys")

if first_valley_frame is not None and third_valley_frame is not None:
    plt.axvline(x=first_valley_frame, color='blue', linestyle='--', label=f"Start: {first_valley_frame}")
    plt.axvline(x=third_valley_frame, color='purple', linestyle='--', label=f"End: {third_valley_frame}")

plt.xlabel("Frame Number")
plt.ylabel("Value")
plt.title("Fallback Gait Cycle (20 Frames from Middle)" if fallback_used else f"Gait Cycle at {angle}°")
plt.legend()
plt.show()
# Out:
# Extracted Angle: 0°
# Initial Gait Cycle Detected: Frame 34 to 58
